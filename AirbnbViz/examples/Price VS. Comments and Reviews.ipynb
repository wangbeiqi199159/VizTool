# %%
import sqlite3
import csv
import pandas as pd
from bokeh.plotting import figure, output_file,output_notebook, show
from bokeh.charts import Scatter, output_file, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7e01ca22-5398-47a9-abb0-9ecfcbbad4ad">Loading BokehJS ...</span>
#     </div>

# %%
sqlite_file = 'review2.db'
conn = sqlite3.connect(sqlite_file)
c = conn.cursor()

# %%
c.execute("drop table Price;")
c.execute("create table Price(ID int NOT NULL, Price int, Number_of_review int, Rating int, primary key (ID));")

# %%
c.execute("drop table Comments;")
c.execute("create table Comments(ID int NOT NULL, Comments varchar(255));")

# %%
with open('id_price_numreview.csv','rt') as price:
    dr = csv.DictReader(price) 
    to_db = [(i['id'], i['price'], i['number_of_reviews'], i['review_scores_rating']) for i in dr]

c.executemany("INSERT INTO Price (ID, Price, Number_of_review, Rating) VALUES (?, ?, ?, ?);", to_db)

# %%
with open('id_comments.csv','rt',errors='ignore') as comment:
    dr1 = csv.DictReader(comment) 
    to_db1 = [(i['ID'], i['Comment']) for i in dr1]

c.executemany("INSERT INTO Comments (ID, Comments) VALUES (?, ?);", to_db1)

# %%
df = pd.read_sql_query("select c.ID, c.Comments, p.Price, p.Number_of_review, p.Rating from Comments c INNER JOIN  Price p ON c.ID = p.ID;", conn)
df.head()
# Out:
#         ID                                           Comments   Price  \
# 0  7202016  Cute and cozy place. Perfect location to every...  $75.00
# 1  7202016  Kelly has a great room in a very central locat...  $75.00
# 2  7202016  Very spacious apartment, and in a great neighb...  $75.00
# 3  7202016  Close to Seattle Center and all it has to offe...  $75.00
# 4  7202016  Kelly was a great host and very accommodating ...  $75.00
#
#    Number_of_review Rating
# 0                16     95
# 1                16     95
# 2                16     95
# 3                16     95
# 4                16     95

# %%
df['Price'] = df['Price'].str.replace('$', '')
df['Price'] = df['Price'].str.replace(',', '')
df['Price'] = df['Price'].astype(float)

# %%
df['Comments'] = df['Comments'].astype(str)

# %%
df.head()
# Out:
#         ID                                           Comments  Price  \
# 0  7202016  Cute and cozy place. Perfect location to every...   75.0
# 1  7202016  Kelly has a great room in a very central locat...   75.0
# 2  7202016  Very spacious apartment, and in a great neighb...   75.0
# 3  7202016  Close to Seattle Center and all it has to offe...   75.0
# 4  7202016  Kelly was a great host and very accommodating ...   75.0
#
#    Number_of_review Rating
# 0                16     95
# 1                16     95
# 2                16     95
# 3                16     95
# 4                16     95

# %%
comments = df['Comments']
comment_lengths = []
for i in range(0, len(comments)):
    comment_lengths.append(len(comments[i]))

# %%
df['comment_length'] = comment_lengths

# %%
df.head()
# Out:
#         ID                                           Comments  Price  \
# 0  7202016  Cute and cozy place. Perfect location to every...   75.0
# 1  7202016  Kelly has a great room in a very central locat...   75.0
# 2  7202016  Very spacious apartment, and in a great neighb...   75.0
# 3  7202016  Close to Seattle Center and all it has to offe...   75.0
# 4  7202016  Kelly was a great host and very accommodating ...   75.0
#
#    Number_of_review Rating  comment_length
# 0                16     95              53
# 1                16     95             390
# 2                16     95             386
# 3                16     95             278
# 4                16     95             334

# %%
df['Rating'] = pd.to_numeric(df['Rating'])

# %%
df_by_id = df.groupby(['ID']).mean()
df_by_id
# Out:
#           Price  Number_of_review  Rating  comment_length
# ID
# 4291       82.0              35.0    92.0      380.800000
# 5682       48.0             297.0    96.0      375.104377
# 6606       90.0              52.0    93.0      384.884615
# 7369       85.0              40.0    94.0      239.775000
# 9419       90.0              79.0    91.0      545.481013
# 9460       99.0             240.0    98.0      549.929167
# 9531      165.0              26.0   100.0      569.692308
# 9534      125.0              14.0   100.0      550.000000
# 9596      120.0              32.0    88.0      413.218750
# 10385      60.0              74.0    94.0      338.162162
# 10695     109.0              12.0    95.0      252.500000
# 11012     310.0              47.0    95.0      541.127660
# 11411      60.0              47.0    93.0      364.212766
# 13068     360.0              26.0    93.0      401.730769
# 14386      40.0              30.0    96.0      390.300000
# 15108      60.0              42.0    86.0      349.904762
# 17951      95.0              21.0    94.0      328.857143
# 19611     107.0              26.0    87.0      509.461538
# 19619     145.0              17.0    98.0      425.411765
# 19623     186.0              38.0    89.0      400.578947
# 20868     137.0              91.0    94.0      320.373626
# 20927      89.0             244.0    97.0      337.790984
# 20928      79.0              44.0    97.0      367.409091
# 23192     119.0               7.0   100.0      162.285714
# 23356     215.0               6.0    83.0      477.666667
# 23430     107.0              22.0    96.0      358.863636
# 23919     165.0               6.0    97.0      413.500000
# 24212     175.0              29.0    91.0      403.482759
# 25002      75.0             404.0    98.0      354.576733
# 26116     199.0             110.0    97.0      482.936364
# ...         ...               ...     ...             ...
# 9694921   196.0               1.0   100.0      957.000000
# 9698202   250.0               4.0    95.0      193.250000
# 9706229   179.0               6.0    87.0      225.833333
# 9711153    40.0               6.0    97.0      210.500000
# 9712716    65.0               3.0   100.0      589.333333
# 9714078   108.0               2.0   100.0      789.000000
# 9727246    92.0               1.0   100.0      325.000000
# 9727857    25.0               3.0   100.0      140.666667
# 9736940    28.0               3.0   100.0      124.666667
# 9797000    75.0               2.0    90.0      438.500000
# 9820818   125.0               1.0   100.0      628.000000
# 9823290    80.0               1.0   100.0      279.000000
# 9849122    35.0               2.0   100.0      172.500000
# 9863484    95.0               2.0   100.0      161.000000
# 9863565    83.0               2.0   100.0      338.500000
# 9865846    85.0               1.0   100.0      620.000000
# 9866461    60.0               1.0    80.0      299.000000
# 9866984    95.0               1.0   100.0      310.000000
# 9908591   100.0               2.0   100.0      180.000000
# 9910025   110.0               1.0   100.0      291.000000
# 9924107   110.0               2.0   100.0      305.000000
# 9929059    99.0               3.0   100.0      179.333333
# 9939359    80.0               2.0    90.0      198.000000
# 9957555   175.0               2.0   100.0      573.000000
# 9970805    39.0               1.0   100.0      212.000000
# 9995551    79.0               1.0   100.0      131.000000
# 10012724   25.0               2.0   100.0      221.500000
# 10020221   55.0               1.0   100.0       96.000000
# 10118341   70.0               1.0   100.0      371.000000
# 10248139   22.0               1.0   100.0      103.000000
#
# [3191 rows x 4 columns]

# %%
p1 = Scatter(df_by_id, x='comment_length', y='Price', title="Price vs Length of Comments",
            xlabel="Length of Comment", ylabel="Listing Price", color = 'navy')

output_file("comment_length_vs_price.html")
show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1e9d4149-a3e1-4af1-93a6-98d97509f017"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("1e9d4149-a3e1-4af1-93a6-98d97509f017").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1e9d4149-a3e1-4af1-93a6-98d97509f017");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1e9d4149-a3e1-4af1-93a6-98d97509f017' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"00178f16-1b50-4208-96cb-89c16fc42a5f":{"roots":{"references":[{"attributes":{"axis_label":"Listing Price","formatter":{"id":"918b8dff-f862-4e90-a0d2-636d39887aeb","type":"BasicTickFormatter"},"plot":{"id":"065caa02-bf43-4030-9bb0-7213ff39b1d7","subtype":"Chart","type":"Plot"},"ticker":{"id":"72f5f9fc-311a-49d4-b07c-2b0114163a55","type":"BasicTicker"}},"id":"0d956825-340e-4ba3-a76b-ab13142891af","type":"LinearAxis"},{"attributes":{"plot":{"id":"065caa02-bf43-4030-9bb0-7213ff39b1d7","subtype":"Chart","type":"Plot"}},"id":"3ed1d6b6-7e7d-44ea-b2c7-9bf7a065c304","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"navy"},"line_color":{"value":"navy"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"274c180c-ae4b-4cc1-a32e-65d2480a3fc3","type":"Circle"},{"attributes":{"axis_label":"Length of Comment","formatter":{"id":"6d299ae1-413a-44d2-8cb1-0ad4d37241e4","type":"BasicTickFormatter"},"plot":{"id":"065caa02-bf43-4030-9bb0-7213ff39b1d7","subtype":"Chart","type":"Plot"},"ticker":{"id":"67ff887f-4009-4fdf-9f03-55c3c9145557","type":"BasicTicker"}},"id":"f1288f99-e250-4040-b7aa-e2e700a03e4a","type":"LinearAxis"},{"attributes":{},"id":"72f5f9fc-311a-49d4-b07c-2b0114163a55","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"44092b9d-2459-4d68-aeb6-a5cc47ea2294","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"065caa02-bf43-4030-9bb0-7213ff39b1d7","subtype":"Chart","type":"Plot"},"ticker":{"id":"67ff887f-4009-4fdf-9f03-55c3c9145557","type":"BasicTicker"}},"id":"60a2024c-6825-4ed8-9383-0ee79290db19","type":"Grid"},{"attributes":{"below":[{"id":"f1288f99-e250-4040-b7aa-e2e700a03e4a","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"0d956825-340e-4ba3-a76b-ab13142891af","type":"LinearAxis"}],"renderers":[{"id":"44092b9d-2459-4d68-aeb6-a5cc47ea2294","type":"BoxAnnotation"},{"id":"2724b760-2782-46c5-a3b4-9c272f875154","type":"GlyphRenderer"},{"id":"9c9282e1-3788-46ca-8fc1-446fbb920a8a","type":"Legend"},{"id":"f1288f99-e250-4040-b7aa-e2e700a03e4a","type":"LinearAxis"},{"id":"0d956825-340e-4ba3-a76b-ab13142891af","type":"LinearAxis"},{"id":"60a2024c-6825-4ed8-9383-0ee79290db19","type":"Grid"},{"id":"43bd79dc-2869-41ba-8225-ee3cc481f6e1","type":"Grid"}],"title":{"id":"b6c7f60c-bed7-4b9b-ae7c-73cecf271f16","type":"Title"},"tool_events":{"id":"453b5694-c87b-487a-af90-00280aadb910","type":"ToolEvents"},"toolbar":{"id":"beb1d583-e088-42ff-a1dc-60709016aa9a","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"5ec8491e-22e6-4a55-9a3f-77de977948ea","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"f3f4bf17-0e63-4fc9-af99-4d1ea0d64980","type":"Range1d"}},"id":"065caa02-bf43-4030-9bb0-7213ff39b1d7","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null ...

# %%
p2 = Scatter(df_by_id, x='Number_of_review', y='Price', title="Price vs Number of Reviews per Listing",
            xlabel="Number of Reviews", ylabel="Listing Price", color = 'firebrick')
output_file("number_of_reviews_vs_price.html")
show(p2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a10fe64e-ad38-4a22-b42c-4410d8615c45"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a10fe64e-ad38-4a22-b42c-4410d8615c45").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a10fe64e-ad38-4a22-b42c-4410d8615c45");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a10fe64e-ad38-4a22-b42c-4410d8615c45' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"594873e7-9d64-4539-a8fa-00389189a425":{"roots":{"references":[{"attributes":{"location":"top_left","plot":{"id":"ee76da99-226e-4043-b0c7-012434d3d77b","subtype":"Chart","type":"Plot"}},"id":"ae8aa6f9-6664-43c4-84d8-e178717e6750","type":"Legend"},{"attributes":{"overlay":{"id":"a392163f-4045-4e00-b0b8-490bca2d0aac","type":"BoxAnnotation"},"plot":{"id":"ee76da99-226e-4043-b0c7-012434d3d77b","subtype":"Chart","type":"Plot"}},"id":"a0b4e046-8110-40ae-9a38-1fe70f3870e5","type":"BoxZoomTool"},{"attributes":{},"id":"b9db7a6e-1692-4a9f-8b25-3251bc5a6914","type":"BasicTicker"},{"attributes":{"plot":{"id":"ee76da99-226e-4043-b0c7-012434d3d77b","subtype":"Chart","type":"Plot"}},"id":"b051b617-94f4-4ad3-86b3-77602709af70","type":"PanTool"},{"attributes":{},"id":"cedb53e1-d681-4a50-849f-9cac55f27757","type":"ToolEvents"},{"attributes":{"plot":{"id":"ee76da99-226e-4043-b0c7-012434d3d77b","subtype":"Chart","type":"Plot"},"ticker":{"id":"c2050232-218f-4272-b135-47d01f96f9cd","type":"BasicTicker"}},"id":"4eecf3bc-1b73-462e-bbf7-ea41c14bc40d","type":"Grid"},{"attributes":{},"id":"bb4dda0b-e9fe-4071-ab22-c5d495ddcf09","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":1097.8,"start":-75.80000000000001},"id":"20e902b4-b1c0-4f79-9553-e78221a233d6","type":"Range1d"},{"attributes":{"callback":null,"end":521.3,"start":-46.300000000000004},"id":"d25e4348-dcee-4227-b122-872ad1b00fd3","type":"Range1d"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nul ...

# %%
p3 = Scatter(df_by_id, x='Rating', y='Price', title="Rating vs Price",
            xlabel="Rating", ylabel="Price", color = 'green')
output_file("rating_vs_price.html")
show(p3)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dc33b712-bbf6-4f38-9fcc-e4ec8f8df5c9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("dc33b712-bbf6-4f38-9fcc-e4ec8f8df5c9").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dc33b712-bbf6-4f38-9fcc-e4ec8f8df5c9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dc33b712-bbf6-4f38-9fcc-e4ec8f8df5c9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8ec6acba-0d88-4892-9a4f-5abab33ece02":{"roots":{"references":[{"attributes":{"plot":{"id":"95f2c313-f479-47fd-b8cc-51c30a1ff81c","subtype":"Chart","type":"Plot"}},"id":"59991bbd-4d05-4c9f-aeca-d40ca4463fd9","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"053f0414-7dc5-437a-86d0-a4889bf92716","type":"BoxAnnotation"},"plot":{"id":"95f2c313-f479-47fd-b8cc-51c30a1ff81c","subtype":"Chart","type":"Plot"}},"id":"27f4122c-410f-412b-aaee-d29124beb1f7","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"green"},"line_color":{"value":"green"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"41105df4-0384-4b81-9a9b-1a33ceedbf95","type":"Circle"},{"attributes":{"axis_label":"Price","formatter":{"id":"77d55f7f-1e88-4763-bd8d-1805fd584b79","type":"BasicTickFormatter"},"plot":{"id":"95f2c313-f479-47fd-b8cc-51c30a1ff81c","subtype":"Chart","type":"Plot"},"ticker":{"id":"bee22a30-b90c-4717-99df-56a8a6d736c5","type":"BasicTicker"}},"id":"663bd5bd-e44a-458a-a4f1-7f64c1ab5853","type":"LinearAxis"},{"attributes":{"plot":null,"text":"Rating vs Price"},"id":"182548e9-776b-4aa8-b503-00045317a3cc","type":"Title"},{"attributes":{"data_source":{"id":"5eb8ba03-c339-40a4-896b-a9b5e90fe3b9","type":"ColumnDataSource"},"glyph":{"id":"41105df4-0384-4b81-9a9b-1a33ceedbf95","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"871dd319-8a26-48a5-8168-884c8b6b4a4f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nul ...
